# %%
import pandas as pd

# Load data
df = pd.read_csv('titanic.csv')
# Out:
# (891, 12)

# %%
# Show first 10 items
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# Show Rows and Columns
df.shape
# Out:
# (891, 12)

# %%
# Method  Describe
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Splitting, Applying, and Combining Data Sources

# %%
# Show groups and mean for group
for name, group in embarked_grouped:
    print(name, group.Age.mean())
# Out:
# C 30.81476923076923
# Q 28.089285714285715
# S 29.44539711191336

# %%
# Using method groupby
embarked_grouped = df.groupby('Embarked')
embarked_grouped.groups
# Out:
# {'C': Int64Index([  1,   9,  19,  26,  30,  31,  34,  36,  39,  42,
#              ...
#              847, 849, 852, 858, 859, 866, 874, 875, 879, 889],
#             dtype='int64', length=168),
#  'Q': Int64Index([  5,  16,  22,  28,  32,  44,  46,  47,  82, 109, 116, 126, 143,
#              156, 171, 186, 188, 196, 198, 208, 214, 241, 245, 260, 264, 274,
#              278, 280, 289, 300, 301, 303, 322, 330, 358, 359, 364, 368, 388,
#              411, 412, 421, 428, 459, 468, 501, 502, 510, 517, 525, 552, 560,
#              573, 593, 612, 613, 626, 629, 653, 654, 657, 680, 697, 703, 718,
#              727, 749, 767, 768, 776, 778, 787, 790, 825, 828, 885, 890],
#             dtype='int64'),
#  'S': Int64Index([  0,   2,   3,   4,   6,   7,   8,  10,  11,  12,
#              ...
#              877, 878, 880, 881, 882, 883, 884, 886, 887, 888],
#             dtype='int64', length=644)}

# %%
Another option is to use the aggregate method, or agg for short, and provide it the function to apply across the columns.
Use the agg method to determine the mean of each group.

# %%
import numpy as np
embarked_grouped.agg(np.mean)
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Embarked
# C          445.357143  0.553571  1.886905  30.814769  0.386905  0.363095
# Q          417.896104  0.389610  2.909091  28.089286  0.428571  0.168831
# S          449.527950  0.336957  2.350932  29.445397  0.571429  0.413043
#
#                Fare
# Embarked
# C         59.954144
# Q         13.276030
# S         27.079812

# %%
age_embarked_grouped = df.groupby(['Sex', 'Embarked'])
age_embarked_grouped.groups
# Out:
# {('male', 'S'): Int64Index([  0,   4,   6,   7,  12,  13,  17,  20,  21,  23,
#              ...
#              870, 872, 873, 876, 877, 878, 881, 883, 884, 886],
#             dtype='int64', length=441),
#  ('female',
#   'C'): Int64Index([  1,   9,  19,  31,  39,  43,  52, 111, 114, 128, 140, 177, 194,
#              195, 215, 218, 240, 255, 256, 258, 291, 299, 306, 307, 309, 310,
#              311, 319, 325, 329, 337, 362, 366, 367, 369, 375, 380, 381, 389,
#              393, 448, 469, 473, 496, 513, 523, 533, 537, 539, 556, 578, 581,
#              591, 608, 641, 644, 691, 700, 702, 710, 716, 742, 780, 830, 835,
#              842, 849, 852, 858, 866, 874, 875, 879],
#             dtype='int64'),
#  ('female', 'S'): Int64Index([  2,   3,   8,  10,  11,  14,  15,  18,  24,  25,
#              ...
#              855, 856, 862, 863, 865, 871, 880, 882, 887, 888],
#             dtype='int64', length=203),
#  ('male',
# ...

# %% [markdown]
# # Managing Missing Data

# %%
#The simplest,but not necessarily the most effective, method is to just remove or ignore those entries 
#that are missing data
#complete_data = df.dropna()
complete_data.shape
# Out:
# (183, 12)

# %%
# Using agg with a Lambda function to identify rows with NaN values
df.aggregate(lambda x: x.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

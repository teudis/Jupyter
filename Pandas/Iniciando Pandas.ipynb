# %%
import pandas as pd

# %%
series = pd.Series([12,34,20,25,46,10])
series
# Out:
# 0    12
# 1    34
# 2    20
# 3    25
# 4    46
# 5    10
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 25

# %%
cad = pd.Series(['p','l','a','t','z','i'])
cad
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object

# %%
lst = ['Hola', 'Pandas','Platzi']
df = pd.DataFrame(lst)
df
# Out:
#         0
# 0    Hola
# 1  Pandas
# 2  Platzi

# %%
df = { 'Nombre':["Thiago", "Annie", "Teudis", "Miguel"], 'Edad':[3,33,35,38], 'Pais':["Cuba","Cuba","Panama","Cuba"]}
df
# Out:
# {'Nombre': ['Thiago', 'Annie', 'Teudis', 'Miguel'],
#  'Edad': [3, 33, 35, 38],
#  'Pais': ['Cuba', 'Cuba', 'Panama', 'Cuba']}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad    Pais
# 0  Thiago     3    Cuba
# 1   Annie    33    Cuba
# 2  Teudis    35  Panama
# 3  Miguel    38    Cuba

# %%
df[['Edad','Nombre']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-4820a21f23da> in <module>
# ----> 1 data[['Edad','Nombre']]
#
# TypeError: unhashable type: 'list'

# %%
data_csv = pd.read_csv('canciones-2018.csv')
data_csv.head(10)
# Out:
#                       id                          name        artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan          Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!   XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)    Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)    Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings          Drake
# 5  7dt6x5M1jzdTEt8oCbisT                    Better Now    Post Malone
# 6  58q2HKrzhC3ozto2nDdN4                     I Like It        Cardi B
# 7  7ef4DlsgrMEH11cDZd32M      One Kiss (with Dua Lipa)  Calvin Harris
# 8  76cy1WJvNGJTj78UqeA5z                         IDGAF       Dua Lipa
# 9  08bNPGLD8AhKpnnERrAc6                       FRIENDS     Marshmello
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449   7.0    -9.211   1.0       0.1090        0.0332
# ...

# %%
data_csv.tail
# Out:
# <bound method NDFrame.tail of                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %%
data_csv.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
artists = data_csv.artists
artists
# Out:
# 0            Drake
# 1     XXXTENTACION
# 2      Post Malone
# 3      Post Malone
# 4            Drake
#           ...
# 95       Zac Efron
# 96    Clean Bandit
# 97       DJ Khaled
# 98            ZAYN
# 99      Dean Lewis
# Name: artists, Length: 100, dtype: object

# %%
data_csv.shape
# Out:
# (100, 16)

# %%
data_csv = pd.read_csv('canciones-2018.csv')
data_csv.sort_index(axis = 0, ascending = False)
# Out:
#                        id                               name       artists  \
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# ..                    ...                                ...           ...
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
#
# ...
